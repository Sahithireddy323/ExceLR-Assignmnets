# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:\\Users\\nimma\\OneDrive\\Desktop\\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
print("Numerical columns:", numerical_cols)
# Out:
# Numerical columns: Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
(df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].mean()) #Mean
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
(df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].median()) #Median
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
(df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].mode()) #Mode
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
import matplotlib.pyplot as plt#Histogram
plt.hist(df['Volume'])
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Avg Price'])
plt.xlabel('Avg Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Total Sales Value'])
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Discount Rate (%)'])
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Discount Amount'])
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Net Sales Value'])
plt.xlabel('Net Sales Value')
plt.ylabel('Frequency')
plt.show()

# %%
t1=df['Date'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
t1=df['Day'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='Day'>

# %%
t1=df['SKU'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='SKU'>

# %%
t1=df['City'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
t1=df['Brand'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
t1=df['Model'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
t1=df['BU'].value_counts() #Bar Chart
t1.plot(kind='bar')
# Out:
# <Axes: xlabel='BU'>

# %%
plt.boxplot(df['Volume'])#Box plot
plt.ylabel('Volume')
plt.show()

# %%
plt.boxplot(df['Avg Price'])#Box plot
plt.ylabel('Avg Price')
plt.show()

# %%
plt.boxplot(df['Total Sales Value'])#Box plot
plt.ylabel('Total Sales Value')
plt.show()

# %%
plt.boxplot(df['Discount Rate (%)'])#Box plot
plt.ylabel('Discount Rate (%)')
plt.show()

# %%
plt.boxplot(df['Discount Amount'])#Box plot
plt.ylabel('Discount Amount')
plt.show()

# %%
plt.boxplot(df['Net Sales Value'])#Box plot
plt.ylabel('Net Sales Value')
plt.show()

# %%
X_cont = df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']] #before and After standardization

# %%
print("before Standardization",X_cont)
# Out:
# before Standardization      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()

SS_X = SS.fit_transform(X_cont)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = [['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']]

# %%
print("After standardization",SS_X)
# Out:
# After standardization        Volume Avg Price Total Sales Value Discount Rate (%) Discount Amount  \
# 0    2.350029  0.091173          2.925721         -0.830289        3.952816
# 1    1.167129 -0.019570          1.330995         -0.852661        1.849014
# 2    0.457388  0.312659          1.562775         -1.351631        1.622995
# 3    0.220808  0.534146          1.719276         -1.949723        1.113807
# 4   -0.488932 -0.130313         -0.188452          0.673739        0.227852
# ..        ...       ...               ...               ...             ...
# 445 -0.725512 -0.506840         -0.618334          0.076009       -0.653541
# 446  0.220808 -0.434857         -0.360801          0.451097       -0.152191
# 447 -0.725512 -0.490229         -0.606448          0.903793       -0.608140
# 448 -0.488932 -0.473617         -0.556923          0.388474       -0.530379
# 449 -0.962092 -0.407171         -0.608429          0.042235       -0.637345
#
#     Net Sales Value
# ...

# %%
one_hot=pd.get_dummies(df,sparse=True) #ONE_HOT ENCODING
one_hot
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...
